# %% [markdown]
# <a href="https://colab.research.google.com/github/RaoMasood1/heart-disease-prediction/blob/main/Heart_Disease_Prediction_By_LogisticRegression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('/content/dataset_heart.csv')

# %%
data.head()
# Out:
#    age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0   70     1                4                     130                322
# 1   67     0                3                     115                564
# 2   57     1                2                     124                261
# 3   64     1                4                     128                263
# 4   74     0                2                     120                269
#
#    fasting blood sugar  resting electrocardiographic results  max heart rate  \
# 0                    0                                     2             109
# 1                    0                                     2             160
# 2                    0                                     0             141
# 3                    0                                     0             105
# 4                    0                                     2             121
#
# ...

# %%
data.tail()
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# 265                    1                                     0
# 266                    0                                     0
# 267                    0                                     2
# 268                    0                                     0
# 269                    0                                     2
#
#      max heart rate  exercise induced angina  oldpeak  ST segment  \
# ...

# %%
data.shape
# Out:
# (270, 14)

# %%
data.info
# Out:
# <bound method DataFrame.info of      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1                4                     130                322
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
# ...

# %%
data.isnull().sum()
# Out:
# age                                     0
# sex                                     0
# chest pain type                         0
# resting blood pressure                  0
# serum cholestoral                       0
# fasting blood sugar                     0
# resting electrocardiographic results    0
# max heart rate                          0
# exercise induced angina                 0
# oldpeak                                 0
# ST segment                              0
# major vessels                           0
# thal                                    0
# heart disease                           0
# dtype: int64

# %%
data.describe()
# Out:
#               age        sex   chest pain type  resting blood pressure  \
# count  270.000000  270.000000       270.000000              270.000000
# mean    54.433333    0.677778         3.174074              131.344444
# std      9.109067    0.468195         0.950090               17.861608
# min     29.000000    0.000000         1.000000               94.000000
# 25%     48.000000    0.000000         3.000000              120.000000
# 50%     55.000000    1.000000         3.000000              130.000000
# 75%     61.000000    1.000000         4.000000              140.000000
# max     77.000000    1.000000         4.000000              200.000000
#
#        serum cholestoral  fasting blood sugar  \
# count         270.000000           270.000000
# mean          249.659259             0.148148
# std            51.686237             0.355906
# min           126.000000             0.000000
# 25%           213.000000             0.000000
# ...

# %%
data['heart disease'].value_counts()
# Out:
# 1    150
# 2    120
# Name: heart disease, dtype: int64

# %%
x= data.drop(columns='heart disease', axis=1)
y= data['heart disease']

# %%
print(x)
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1                4                     130                322
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# ...

# %%
print(y)
# Out:
# 0      2
# 1      1
# 2      2
# 3      1
# 4      1
#       ..
# 265    1
# 266    1
# 267    1
# 268    1
# 269    2
# Name: heart disease, Length: 270, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,stratify=y, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (270, 13) (216, 13) (54, 13)

# %%
model= LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_train_prediction= model.predict(x_train)
accu= accuracy_score(x_train_prediction, y_train)

# %%
print(accu)
# Out:
# 0.875

# %%
x_test_prediction= model.predict(x_test)
test_accu= accuracy_score(x_test_prediction, y_test)

# %%
print(test_accu)
# Out:
# 0.8333333333333334

# %%
input=(57,1,3,150,126,1,0,173,0,0.2,1,1,7)

inp= np.asarray(input)

res= inp.reshape(1,-1)
predicton = model.predict(res)

print(predicton)

if(predicton==1):
  print('the person does not have any heart disease')
else:
  print('the person has heart disease')
# Out:
# [1]
# the person does not have any heart disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
inpt=(61,1,4,138,166,0,2,125,1,3.6,2,1,3)

inpu= np.asarray(inpt)

res= inpu.reshape(1,-1)
predicton = model.predict(res)

print(predicton)

if(predicton==1):
  print('the person does not have any heart disease')
else:
  print('the person has heart disease')
# Out:
# [2]
# the person has heart disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
